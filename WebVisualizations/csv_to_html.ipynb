# %%
# Dependencies
import pandas as pd

# Save path to data set in a variable
data_file = "Resources/cities.csv"

# Use Pandas to read data
data_file_df = pd.read_csv(data_file)
data_file_df.set_index('City_ID', inplace=True)
data_file_df.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0        jacareacanga           0      BR  1528902000        62  -6.22
# 1          kaitangata         100      NZ  1528905304        94 -46.28
# 2            goulburn          20      AU  1528905078        91 -34.75
# 3                lata          76      IN  1528905305        89  30.78
# 4          chokurdakh           0      RU  1528905306        88  70.62
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0        -57.76     89.60        6.93
# 1        169.85     42.61        5.64
# 2        149.72     44.32       10.11
# 3         78.62     59.89        0.94
# 4        147.90     32.17        2.95

# %%
html_table = data_file_df.to_html()
html_table
# Out:
# 03800</td>\n      <td>64</td>\n      <td>47.55</td>\n      <td>-2.56</td>\n      <td>69.80</td>\n      <td>8.05</td>\n    </tr>\n    <tr>\n      <th>470</th>\n      <td>470</td>\n      <td>bilibino</td>\n      <td>0</td>\n      <td>RU</td>\n      <td>1528905560</td>\n      <td>60</td>\n      <td>68.06</td>\n      <td>166.44</td>\n      <td>52.33</td>\n      <td>1.95</td>\n    </tr>\n    <tr>\n      <th>471</th>\n      <td>471</td>\n      <td>jiangyou</td>\n      <td>92</td>\n      <td>CN</td>\n      <td>1528905561</td>\n      <td>64</td>\n      <td>31.78</td>\n      <td>104.73</td>\n      <td>73.30</td>\n      <td>4.18</td>\n    </tr>\n    <tr>\n      <th>472</th>\n      <td>472</td>\n      <td>ambilobe</td>\n      <td>8</td>\n      <td>MG</td>\n      <td>1528905561</td>\n      <td>44</td>\n      <td>-13.19</td>\n      <td>49.05</td>\n      <td>80.95</td>\n      <td>13.80</td>\n    </tr>\n    <tr>\n      <th>473</th>\n      <td>473</td>\n      <td>shebunino</td>\n      <td>0</td>\n  
# ...

# %%
html_table.replace('\n', '')
# Out:
# td>      <td>1.95</td>    </tr>    <tr>      <th>461</th>      <td>461</td>      <td>narsimhapur</td>      <td>88</td>      <td>IN</td>      <td>1528905558</td>      <td>78</td>      <td>17.14</td>      <td>74.26</td>      <td>76.00</td>      <td>9.22</td>    </tr>    <tr>      <th>462</th>      <td>462</td>      <td>sao joao da barra</td>      <td>0</td>      <td>BR</td>      <td>1528902000</td>      <td>43</td>      <td>-21.64</td>      <td>-41.05</td>      <td>87.80</td>      <td>5.82</td>    </tr>    <tr>      <th>463</th>      <td>463</td>      <td>mamakan</td>      <td>32</td>      <td>RU</td>      <td>1528905559</td>      <td>83</td>      <td>57.82</td>      <td>114.02</td>      <td>51.70</td>      <td>2.06</td>    </tr>    <tr>      <th>464</th>      <td>464</td>      <td>inirida</td>      <td>80</td>      <td>CO</td>      <td>1528905559</td>      <td>84</td>      <td>3.87</td>      <td>-67.92</td>      <td>80.32</td>      <td>2.95</td>    </tr>    <tr>      <th>465</th>     
# ...

# %%
data_file_df.to_html('table.html')
